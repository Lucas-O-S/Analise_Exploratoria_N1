# %% [markdown]
# <a rel="license" href="https://faculdadesalvadorarena.org.br/"><img alt="FESA" style="border-width:0" src="https://faculdadesalvadorarena.org.br/wp-content/uploads/2022/07/logo_fesa.png" /></a><br />
# **FESA - Eletiva II (2025.1)** <br/>
#
# Aluno(a): Lucas Oliveira Silva
#  <br/>
# Data: 15/02/2025 <br/>
# Tabela: Links

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %% [markdown]
# ## 1. Explorando o Dataset

# %% [markdown]
# Dataset fictício Movie Lens (small). <br/>
# https://grouplens.org/datasets/movielens/

# %% [markdown]
# ### 1.1. Importando o Dataset

# %%
df = pd.read_csv('/content/links.csv')

# %%
df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ### 1.2. Informações básicas do dataset

# %%
print(f'O dataset possui {df.shape[0]} exemplos/amostras/linhas e {df.shape[1]} atributos/variáveis/colunas.')
# Out:
# O dataset possui 9742 exemplos/amostras/linhas e 3 atributos/variáveis/colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %% [markdown]
# ### 1.2. Corrigindo Dataset

# %% [markdown]
# O tipo de tmdbId está como float, como id não deve ter casa decimal vamos corrigir esse dado <br/>

# %%
print(df.isnull().sum())
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64

# %% [markdown]
# Foi verificado valores faltando e tmdbid

# %% [markdown]
# #### 1.2.1 Alterando Nome das colunas

# %%
df.columns = ["Id de Filme","Id IMDB", "Id TMDB"]

# %% [markdown]
# #### 1.2.2 Corrigindo Tag

# %%
df["Id TMDB"] = df["Id TMDB"].fillna(0).astype(int)

# %% [markdown]
# ### 1.3 Verificando resultado

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id de Filme  9742 non-null   int64
#  1   Id IMDB      9742 non-null   int64
#  2   Id TMDB      9742 non-null   int64
# dtypes: int64(3)
# memory usage: 228.5 KB

# %%
df.head()
# Out:
#    Id de Filme  Id IMDB  Id TMDB
# 0            1   114709      862
# 1            2   113497     8844
# 2            3   113228    15602
# 3            4   114885    31357
# 4            5   113041    11862

# %%
df.describe()
# Out:
#          Id de Filme       Id IMDB        Id TMDB
# count    9742.000000  9.742000e+03    9742.000000
# mean    42200.353623  6.771839e+05   55116.825395
# std     52160.494854  1.107228e+06   93628.351521
# min         1.000000  4.170000e+02       0.000000
# 25%      3248.250000  9.518075e+04    9656.750000
# 50%      7300.000000  1.672605e+05   16497.500000
# 75%     76232.000000  8.055685e+05   44147.750000
# max    193609.000000  8.391976e+06  525662.000000
